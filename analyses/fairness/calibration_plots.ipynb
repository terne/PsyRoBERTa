# %%
import numpy as np 
import pandas as pd
from sklearn.calibration import calibration_curve
from sklearn.metrics import brier_score_loss
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
# setting path
sys.path.append('..')
from utils.eval_utils import get_temp_df

# %%
dischargesum_psyroberta_p4_epoch12 = pd.read_csv("../../result_files/dischargesum_psyroberta_p4_epoch12_results.csv")
dischargesum_roberta_epoch12 = pd.read_csv("../../result_files/forward_explain_out/dischargesum_roberta_epoch12_results.csv")

allnotes_psyroberta_p4_epoch12 = pd.read_csv("../../result_files/allnotes_psyroberta_p4_epoch12_results.csv")
allnotes_psyroberta_p4_dedupcont_epoch12 = pd.read_csv("../../result_files/allnotes_psyroberta_p4_dedupcont_epoch12_results.csv")
allnotes_roberta_dedupcont_epoch12 = pd.read_csv("../../result_files/allnotes_roberta_dedupcont_epoch12_results.csv")

dischargesum_medabert = pd.read_csv("../../result_files/dischargesum_medabert_results.csv")
allnotes_medabert_dedupcont = pd.read_csv("../../result_files/allnotes_medabert_results.csv")

dischargesum_bert = pd.read_csv("../../result_files/dischargesum_bert_results.csv")
allnotes_bert_dedupcont = pd.read_csv("../../result_files/allnotes_bert_results.csv")

# %%
EPOCH=11

# %%
res = dischargesum_psyroberta_p4_epoch12[dischargesum_psyroberta_p4_epoch12.epoch==EPOCH]
model_name = "Psyroberta (Discharge Summaries)"

#temp_train = get_temp_df(res, split="train")
#temp_val = get_temp_df(res, split="val")
temp_test = get_temp_df(res, split="test")


prob_true, prob_pred = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
res = allnotes_psyroberta_p4_dedupcont_epoch12[allnotes_psyroberta_p4_dedupcont_epoch12.epoch==EPOCH]
model_name = "Psyroberta (All notes)"

temp_test = get_temp_df(res, split="test")

prob_true_all, prob_pred_all = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)

# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
res = allnotes_medabert_dedupcont[allnotes_medabert_dedupcont.epoch==EPOCH]
model_name = "MeDa-BERT (All notes)"

temp_test = get_temp_df(res, split="test")

prob_true_all_meda, prob_pred_all_meda = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
res = allnotes_roberta_dedupcont_epoch12[allnotes_roberta_dedupcont_epoch12.epoch==EPOCH]
model_name = "Roberta (All notes)"

temp_test = get_temp_df(res, split="test")

prob_true_all_rob, prob_pred_all_rob = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
res = allnotes_bert_dedupcont[allnotes_bert_dedupcont.epoch==EPOCH]
model_name = "BERT (All notes)"

temp_test = get_temp_df(res, split="test")

prob_true_all_bert, prob_pred_all_bert = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
#dischargesum_roberta
res = dischargesum_roberta_epoch12[dischargesum_roberta_epoch12.epoch==EPOCH]
model_name = "Roberta (Discharge Summaries)"

temp_test = get_temp_df(res, split="test")


prob_true_dis_rob, prob_pred_dis_rob = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
#dischargesum_medabert
res = dischargesum_medabert[dischargesum_medabert.epoch==EPOCH]
model_name = "MeDa-BERT (Discharge Summaries)"

temp_test = get_temp_df(res, split="test")

prob_true_dis_meda, prob_pred_dis_meda = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
#dischargesum_bert
res = dischargesum_bert[dischargesum_bert.epoch==EPOCH]
model_name = "BERT (Discharge Summaries)"

temp_test = get_temp_df(res, split="test")


prob_true_dis_bert, prob_pred_dis_bert = calibration_curve(y_true=temp_test.target, 
                                         y_prob=temp_test.p_mean,
                                         pos_label=1, 
                                         n_bins=20)
# Brier Score
b_score = brier_score_loss(temp_test.target, temp_test.p_mean)
print("Brier Score :",b_score)

# %%
sns.set(style="whitegrid")
sns.set_palette('mako_r', n_colors=4)


fig, ax = plt.subplots(figsize=(7,5))

plt.plot(prob_pred_all,prob_true_all, marker="o", label="PsyRoBERTa")
#plt.plot(prob_pred,prob_true, marker="o", label="PsyRoBERTa (Discharge summaries)")

plt.plot(prob_pred_all_meda,prob_true_all_meda, marker="o", label="MeDa-BERT")
#plt.plot(prob_pred_dis_meda,prob_true_dis_meda, marker="o", label="MeDa-BERT (Discharge summaries)")

plt.plot(prob_pred_all_rob,prob_true_all_rob, marker="o", label="RøBÆRTa")
#plt.plot(prob_pred_dis_rob,prob_true_dis_rob, marker="o", label="RøBÆRTa (Discharge summaries)")

plt.plot(prob_pred_all_bert,prob_true_all_bert, marker="o", label="BERT")
#plt.plot(prob_pred_dis_bert,prob_true_dis_bert, marker="o", label="BERT (Discharge summaries)")

#Plot the Perfectly Calibrated by Adding the 45-degree line to the plot
plt.plot([0, 1], 
         [0, 1], 
         linestyle='--',
         color="black",
         label='Perfectly calibrated')

# Set the title and axis labels for the plot
#plt.title('Probability Calibration Curve')
plt.xlabel('Predicted probability (20 bins)')
plt.ylabel('Observed probability (20 bins)')
 
# Add a legend to the plot
plt.legend(loc='best')

plt.savefig("../figures_to_download/calibration_curve_allnotes.pdf", bbox_inches="tight")
plt.savefig("../figures_to_download/calibration_curve_allnotes.png", bbox_inches="tight")

# %%
fig, ax = plt.subplots(figsize=(7,5))

#plt.plot(prob_pred_all,prob_true_all, marker="o", label="PsyRoBERTa (All admission notes)")
plt.plot(prob_pred,prob_true, marker="o", label="PsyRoBERTa")

#plt.plot(prob_pred_all_meda,prob_true_all_meda, marker="o", label="MeDa-BERT (All admission notes)")
plt.plot(prob_pred_dis_meda,prob_true_dis_meda, marker="o", label="MeDa-BERT")

#plt.plot(prob_pred_all_rob,prob_true_all_rob, marker="o", label="RøBÆRTa (All admission notes)")
plt.plot(prob_pred_dis_rob,prob_true_dis_rob, marker="o", label="RøBÆRTa")

#plt.plot(prob_pred_all_bert,prob_true_all_bert, marker="o", label="BERT (All admission notes)")
plt.plot(prob_pred_dis_bert,prob_true_dis_bert, marker="o", label="BERT")

#Plot the Perfectly Calibrated by Adding the 45-degree line to the plot
plt.plot([0, 1], 
         [0, 1], 
         linestyle='--',
         color="black",
         label='Perfectly calibrated')

# Set the title and axis labels for the plot
#plt.title('Probability Calibration Curve')
plt.xlabel('Predicted probability (20 bins)')
plt.ylabel('Observed probability (20 bins)')
 
# Add a legend to the plot
plt.legend(loc='best')

plt.savefig("../figures_to_download/calibration_curve_dischargesum.pdf", bbox_inches="tight")
plt.savefig("../figures_to_download/calibration_curve_dischargesum.png", bbox_inches="tight")
